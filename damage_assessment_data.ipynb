# %%
# importing utility functions
import pandas as pd
import numpy as np
import os
import sys


# %load_ext autoreload
# %autoreload 2

module_path = os.path.abspath(os.path.join( 'src'))
if module_path not in sys.path:
    sys.path.append(module_path)
    
from nb_modules import cleaning_mod as cl

# %%
df= pd.read_csv('data/extracted/eq_data/csv_building_damage_assessment.csv', dtype='unicode')

# %%
# df.head()

# %%
df.columns
# Out:
# Index(['building_id', 'district_id', 'vdcmun_id', 'ward_id',
#        'damage_overall_collapse', 'damage_overall_leaning',
#        'damage_overall_adjacent_building_risk', 'damage_foundation_severe',
#        'damage_foundation_moderate', 'damage_foundation_insignificant',
#        'damage_roof_severe', 'damage_roof_moderate',
#        'damage_roof_insignificant', 'damage_corner_separation_severe',
#        'damage_corner_separation_moderate',
#        'damage_corner_separation_insignificant',
#        'damage_diagonal_cracking_severe', 'damage_diagonal_cracking_moderate',
#        'damage_diagonal_cracking_insignificant',
#        'damage_in_plane_failure_severe', 'damage_in_plane_failure_moderate',
#        'damage_in_plane_failure_insignificant',
#        'damage_out_of_plane_failure_severe',
#        'damage_out_of_plane_failure_moderate',
#        'damage_out_of_plane_failure_insignificant',
#        'damage_out_of_plane_failure_walls_ncfr_severe',
#        'damage_out_of_plane_failure_walls_ncfr_moderate',
#        'damage_out_of_plane_failure_walls_ncfr_insignificant',
#        'damage_gable_failure_severe', 'damage_gable_failure_moderate',
#        'damage_gable_failure_insignificant',
#        'damage_delamination_failure_severe',
#        'damage_delamination_failure_moderate',
#        'damage_delamination_failure_insignificant',
#        'damage_column_failure_severe', 'damage_column_failure_moderate',
#        'damage_column_failure_insignificant', 'damage_beam_failure_severe',
#        'damage_beam_failure_moderate', 'damage_beam_failure_insignificant',
#        'damage_infill_partition_failure_severe',
#        'damage_infill_partition_failure_moderate',
#        'damage_infill_partition_failure_insignificant',
#        'damage_staircase_severe', 'damage_staircase_moderate',
#        'damage_staircase_insignificant', 'damage_parapet_severe',
#        'damage_parapet_moderate', 'damage_parapet_insignificant',
#        'damage_cladding_glazing_severe', 'damage_cladding_glazing_moderate',
#        'damage_cladding_glazing_insignificant', 'area_assesed', 'damage_grade',
#        'technical_solution_proposed', 'has_repair_started',
#        'has_damage_foundation', 'has_damage_roof',
#        'has_damage_corner_separation', 'has_damage_diagonal_cracking',
#        'has_damage_in_plane_failure', 'has_damage_out_of_plane_failure',
#        'has_damage_out_of_plane_walls_ncfr_failure',
#        'has_damage_gable_failure', 'has_damage_delamination_failure',
#        'has_damage_column_failure', 'has_damage_beam_failure',
#        'has_damage_infill_partition_failure', 'has_damage_staircase',
#        'has_damage_parapet', 'has_damage_cladding_glazing',
#        'has_geotechnical_risk', 'has_geotechnical_risk_land_settlement',
#        'has_geotechnical_risk_fault_crack',
#        'has_geotechnical_risk_liquefaction', 'has_geotechnical_risk_landslide',
#        'has_geotechnical_risk_rock_fall', 'has_geotechnical_risk_flood',
#        'has_geotechnical_risk_other'],
#       dtype='object')

# %%
damage_df= df[['building_id','damage_grade', 'technical_solution_proposed','damage_overall_collapse', 'damage_overall_leaning',
       'damage_overall_adjacent_building_risk', 'damage_foundation_severe',
       'damage_foundation_moderate', 'damage_foundation_insignificant','has_damage_foundation',
              'has_damage_roof',
       'has_damage_corner_separation', 'has_damage_diagonal_cracking',
       'has_damage_in_plane_failure', 'has_damage_out_of_plane_failure',
       'has_damage_out_of_plane_walls_ncfr_failure',
       'has_damage_gable_failure', 'has_damage_delamination_failure',
       'has_damage_column_failure', 'has_damage_beam_failure',
       'has_damage_infill_partition_failure', 'has_damage_staircase',
       'has_damage_parapet', 'has_damage_cladding_glazing']]

# %%
damage_df.head()
# Out:
#     building_id damage_grade technical_solution_proposed  \
# 0  120101000011      Grade 3                Major repair
# 1  120101000021      Grade 5              Reconstruction
# 2  120101000031      Grade 2                Minor repair
# 3  120101000041      Grade 2                Minor repair
# 4  120101000051      Grade 1                Minor repair
#
#   damage_overall_collapse damage_overall_leaning  \
# 0          Moderate-Heavy    Insignificant/light
# 1          Severe-Extreme         Severe-Extreme
# 2          Moderate-Heavy         Moderate-Heavy
# 3          Moderate-Heavy         Moderate-Heavy
# 4     Insignificant/light                   None
#
#   damage_overall_adjacent_building_risk damage_foundation_severe  \
# 0                                  None                      NaN
# 1                   Insignificant/light    Severe-Extreme-(>2/3)
# 2                        Moderate-Heavy                      NaN
# 3                        Moderate-Heavy                      NaN
# 4                                  None                      NaN
#
#   damage_foundation_moderate damage_foundation_insignificant  \
# 0      Moderate-Heavy-(<1/3)      Insignificant/light-(<1/3)
# 1                        NaN                             NaN
# 2      Moderate-Heavy-(>2/3)                             NaN
# 3      Moderate-Heavy-(>2/3)                             NaN
# 4                        NaN      Insignificant/light-(<1/3)
#
#   has_damage_foundation  ... has_damage_out_of_plane_failure  \
# 0                   NaN  ...                             NaN
# 1                     1  ...                               1
# 2                   NaN  ...                             NaN
# 3                   NaN  ...                             NaN
# 4                   NaN  ...                             NaN
#
#   has_damage_out_of_plane_walls_ncfr_failure has_damage_gable_failure  \
# 0                                          1                        0
# 1                                          1                        0
# 2                                        NaN                      NaN
# 3                                        NaN                      NaN
# 4                                        NaN                        0
#
#   has_damage_delamination_failure has_damage_column_failure  \
# 0                               0                       NaN
# 1                               1                       NaN
# 2                             NaN                       NaN
# 3                             NaN                       NaN
# 4                               0                       NaN
#
#   has_damage_beam_failure has_damage_infill_partition_failure  \
# 0                     NaN                                 NaN
# 1                     NaN                                 NaN
# 2                     NaN                                 NaN
# 3                     NaN                                 NaN
# 4                     NaN                                 NaN
#
#   has_damage_staircase has_damage_parapet has_damage_cladding_glazing
# 0                    0                  0                           0
# 1                    0                  0                           0
# 2                    1                  0                           0
# 3                  NaN                  0                           0
# 4                    0                  0                           0
#
# [5 rows x 24 columns]

# %%
damage_df[damage_df['damage_grade'].isna()]
# Out:
#          building_id damage_grade technical_solution_proposed  \
# 83988   203202000521          NaN                         NaN
# 131368  212402000091          NaN                         NaN
# 131631  212402000211          NaN                         NaN
# 131652  212402000221          NaN                         NaN
# 131699  212402000071          NaN                         NaN
# 131711  212402000201          NaN                         NaN
# 131723  212402000341          NaN                         NaN
# 131725  212402000361          NaN                         NaN
# 131726  212402000371          NaN                         NaN
# 131727  212402000381          NaN                         NaN
# 132001  212404000861          NaN                         NaN
# 132004  212404000881          NaN                         NaN
#
#        damage_overall_collapse damage_overall_leaning  \
# 83988                      NaN                    NaN
# 131368          Moderate-Heavy                   None
# 131631          Moderate-Heavy                    NaN
# 131652                     NaN                    NaN
# 131699          Moderate-Heavy                   None
# 131711                     NaN                    NaN
# 131723                     NaN                    NaN
# 131725                     NaN                    NaN
# 131726                     NaN                    NaN
# 131727                     NaN                    NaN
# 132001                     NaN                    NaN
# 132004                     NaN                    NaN
#
#        damage_overall_adjacent_building_risk damage_foundation_severe  \
# 83988                                    NaN                      NaN
# 131368                                  None                     None
# 131631                                   NaN                      NaN
# 131652                                   NaN                      NaN
# 131699                                  None                      NaN
# 131711                                   NaN                      NaN
# 131723                                   NaN                      NaN
# 131725                                   NaN                      NaN
# 131726                                   NaN                      NaN
# 131727                                   NaN                      NaN
# 132001                                   NaN                      NaN
# 132004                                   NaN                      NaN
#
#        damage_foundation_moderate damage_foundation_insignificant  \
# 83988                         NaN                             NaN
# 131368                        NaN                             NaN
# 131631                        NaN                             NaN
# 131652                        NaN                             NaN
# 131699                        NaN                             NaN
# 131711                        NaN                             NaN
# 131723                        NaN                             NaN
# 131725                        NaN                             NaN
# 131726                        NaN                             NaN
# 131727                        NaN                             NaN
# 132001                        NaN                             NaN
# 132004                        NaN                             NaN
#
#        has_damage_foundation  ... has_damage_out_of_plane_failure  \
# 83988                    NaN  ...                             NaN
# 131368                     0  ...                             NaN
# 131631                   NaN  ...                             NaN
# 131652                   NaN  ...                             NaN
# 131699                   NaN  ...                             NaN
# 131711                   NaN  ...                             NaN
# 131723                   NaN  ...                             NaN
# 131725                   NaN  ...                             NaN
# 131726                   NaN  ...                             NaN
# 131727                   NaN  ...                             NaN
# 132001                   NaN  ...                             NaN
# 132004                   NaN  ...                             NaN
#
#        has_damage_out_of_plane_walls_ncfr_failure has_damage_gable_failure  \
# 83988                                         NaN                      NaN
# 131368                                        NaN                      NaN
# 131631                                        NaN                      NaN
# 131652                                        NaN                      NaN
# 131699                                        NaN                      NaN
# 131711                                        NaN                      NaN
# 131723                                        NaN                      NaN
# 131725                                        NaN                      NaN
# 131726                                        NaN                      NaN
# 131727                                        NaN                      NaN
# 132001                                        NaN                      NaN
# 132004                                        NaN                      NaN
#
#        has_damage_delamination_failure has_damage_column_failure  \
# 83988                              NaN                       NaN
# 131368                             NaN                       NaN
# 131631                             NaN                       NaN
# 131652                             NaN                       NaN
# 131699                             NaN                       NaN
# 131711                             NaN                       NaN
# 131723                             NaN                       NaN
# 131725                             NaN                       NaN
# 131726                             NaN                       NaN
# 131727                             NaN                       NaN
# 132001                             NaN                       NaN
# 132004                             NaN                       NaN
#
#        has_damage_beam_failure has_damage_infill_partition_failure  \
# 83988                      NaN                                 NaN
# 131368                     NaN                                 NaN
# 131631                     NaN                                 NaN
# 131652                     NaN                                 NaN
# 131699                     NaN                                 NaN
# 131711                     NaN                                 NaN
# 131723                     NaN                                 NaN
# 131725                     NaN                                 NaN
# 131726                     NaN                                 NaN
# 131727                     NaN                                 NaN
# 132001                     NaN                                 NaN
# 132004                     NaN                                 NaN
#
#        has_damage_staircase has_damage_parapet has_damage_cladding_glazing
# 83988                   NaN                NaN                         NaN
# 131368                  NaN                NaN                         NaN
# 131631                  NaN                NaN                         NaN
# 131652                  NaN                NaN                         NaN
# 131699                  NaN                NaN                         NaN
# 131711                  NaN                NaN                         NaN
# 131723                  NaN                NaN                         NaN
# 131725                  NaN                NaN                         NaN
# 131726                  NaN                NaN                         NaN
# 131727                  NaN                NaN                         NaN
# 132001                  NaN                NaN                         NaN
# 132004                  NaN                NaN                         NaN
#
# [12 rows x 24 columns]

# %%
pd.set_option('display.max_columns', None)
damage_df[damage_df['damage_grade']=='Grade 1'].head(10)
# Out:
#      building_id damage_grade technical_solution_proposed  \
# 4   120101000051      Grade 1                Minor repair
# 11  120101000121      Grade 1                Minor repair
# 12  120101000131      Grade 1                     No need
# 14  120101000151      Grade 1                     No need
# 15  120101000161      Grade 1                     No need
# 21  120101000211      Grade 1                Minor repair
# 22  120101000212      Grade 1                     No need
# 27  120101000261      Grade 1                     No need
# 28  120101000271      Grade 1                     No need
# 29  120101000281      Grade 1                Minor repair
#
#    damage_overall_collapse damage_overall_leaning  \
# 4      Insignificant/light                   None
# 11                    None                   None
# 12                    None                   None
# 14     Insignificant/light                   None
# 15                    None                   None
# 21                    None                   None
# 22                    None                   None
# 27                    None                   None
# 28                    None                   None
# 29                    None                   None
#
#    damage_overall_adjacent_building_risk damage_foundation_severe  \
# 4                                   None                      NaN
# 11                                  None                     None
# 12                                  None                     None
# 14                                  None                     None
# 15                                  None                     None
# 21                                  None                      NaN
# 22                                  None                     None
# 27                                  None                     None
# 28                                  None                     None
# 29                                  None                     None
#
#    damage_foundation_moderate damage_foundation_insignificant  \
# 4                         NaN      Insignificant/light-(<1/3)
# 11                        NaN                             NaN
# 12                        NaN                             NaN
# 14                        NaN                             NaN
# 15                        NaN                             NaN
# 21                        NaN      Insignificant/light-(<1/3)
# 22                        NaN                             NaN
# 27                        NaN                             NaN
# 28                        NaN                             NaN
# 29                        NaN                             NaN
#
#    has_damage_foundation has_damage_roof has_damage_corner_separation  \
# 4                    NaN             NaN                          NaN
# 11                     0               0                          NaN
# 12                     0               0                            0
# 14                     0             NaN                          NaN
# 15                     0               0                          NaN
# 21                   NaN             NaN                          NaN
# 22                     0             NaN                          NaN
# 27                     0               0                          NaN
# 28                     0               0                            0
# 29                     0               0                            0
#
#    has_damage_diagonal_cracking has_damage_in_plane_failure  \
# 4                           NaN                         NaN
# 11                          NaN                         NaN
# 12                          NaN                           0
# 14                          NaN                         NaN
# 15                            0                           0
# 21                          NaN                         NaN
# 22                          NaN                         NaN
# 27                          NaN                         NaN
# 28                            0                           0
# 29                          NaN                         NaN
#
#    has_damage_out_of_plane_failure has_damage_out_of_plane_walls_ncfr_failure  \
# 4                              NaN                                        NaN
# 11                             NaN                                        NaN
# 12                             NaN                                        NaN
# 14                             NaN                                        NaN
# 15                             NaN                                        NaN
# 21                             NaN                                        NaN
# 22                             NaN                                        NaN
# 27                             NaN                                        NaN
# 28                               0                                          0
# 29                             NaN                                        NaN
#
#    has_damage_gable_failure has_damage_delamination_failure  \
# 4                         0                               0
# 11                      NaN                               0
# 12                      NaN                               0
# 14                      NaN                               0
# 15                      NaN                               0
# 21                      NaN                               0
# 22                        0                               0
# 27                      NaN                               0
# 28                        1                               0
# 29                        0                               0
#
#    has_damage_column_failure has_damage_beam_failure  \
# 4                        NaN                     NaN
# 11                       NaN                     NaN
# 12                       NaN                     NaN
# 14                       NaN                     NaN
# 15                       NaN                     NaN
# 21                       NaN                     NaN
# 22                       NaN                     NaN
# 27                       NaN                     NaN
# 28                       NaN                     NaN
# 29                       NaN                     NaN
#
#    has_damage_infill_partition_failure has_damage_staircase  \
# 4                                  NaN                    0
# 11                                 NaN                    0
# 12                                 NaN                    0
# 14                                 NaN                    1
# 15                                 NaN                    1
# 21                                 NaN                    1
# 22                                 NaN                    1
# 27                                 NaN                    1
# 28                                 NaN                    0
# 29                                 NaN                    1
#
#    has_damage_parapet has_damage_cladding_glazing
# 4                   0                           0
# 11                NaN                           0
# 12                NaN                           0
# 14                NaN                           0
# 15                NaN                           0
# 21                NaN                           0
# 22                NaN                           0
# 27                NaN                           0
# 28                  0                           0
# 29                NaN                           0

# %%
# damage_df['damage_overall_collapse'].value_counts()

# %%
# damage_df['damage_overall_collapse'].isna().sum()

# %%
# damage_df['damage_overall_leaning'].value_counts()

# %%
# damage_df['has_geotechnical_risk'].value_counts()

# %%
geotech_risk_df=df[['building_id', 'district_id', 'vdcmun_id', 'ward_id', 'has_geotechnical_risk', 'has_geotechnical_risk_land_settlement',
       'has_geotechnical_risk_fault_crack',
       'has_geotechnical_risk_liquefaction', 'has_geotechnical_risk_landslide',
       'has_geotechnical_risk_rock_fall', 'has_geotechnical_risk_flood',
       'has_geotechnical_risk_other']]

# %%
geotech_risk_df[geotech_risk_df['has_geotechnical_risk'].isna()]
# Out:
#          building_id district_id vdcmun_id ward_id has_geotechnical_risk  \
# 83988   203202000521          20      2009  200910                   NaN
# 131368  212402000091          21      2107  210703                   NaN
# 131631  212402000211          21      2107  210703                   NaN
# 131652  212402000221          21      2107  210703                   NaN
# 131699  212402000071          21      2107  210703                   NaN
# 131711  212402000201          21      2107  210703                   NaN
# 131723  212402000341          21      2107  210703                   NaN
# 131725  212402000361          21      2107  210703                   NaN
# 131726  212402000371          21      2107  210703                   NaN
# 131727  212402000381          21      2107  210703                   NaN
# 132001  212404000861          21      2107  210703                   NaN
# 132004  212404000881          21      2107  210703                   NaN
#
#        has_geotechnical_risk_land_settlement  \
# 83988                                      0
# 131368                                     0
# 131631                                     0
# 131652                                     0
# 131699                                     0
# 131711                                     0
# 131723                                     0
# 131725                                     0
# 131726                                     0
# 131727                                     0
# 132001                                     0
# 132004                                     0
#
#        has_geotechnical_risk_fault_crack has_geotechnical_risk_liquefaction  \
# 83988                                  0                                  0
# 131368                                 0                                  0
# 131631                                 0                                  0
# 131652                                 0                                  0
# 131699                                 0                                  0
# 131711                                 0                                  0
# 131723                                 0                                  0
# 131725                                 0                                  0
# 131726                                 0                                  0
# 131727                                 0                                  0
# 132001                                 0                                  0
# 132004                                 0                                  0
#
#        has_geotechnical_risk_landslide has_geotechnical_risk_rock_fall  \
# 83988                                0                               0
# 131368                               0                               0
# 131631                               0                               0
# 131652                               0                               0
# 131699                               0                               0
# 131711                               0                               0
# 131723                               0                               0
# 131725                               0                               0
# 131726                               0                               0
# 131727                               0                               0
# 132001                               0                               0
# 132004                               0                               0
#
#        has_geotechnical_risk_flood has_geotechnical_risk_other
# 83988                            0                           0
# 131368                           0                           0
# 131631                           0                           0
# 131652                           0                           0
# 131699                           0                           0
# 131711                           0                           0
# 131723                           0                           0
# 131725                           0                           0
# 131726                           0                           0
# 131727                           0                           0
# 132001                           0                           0
# 132004                           0                           0

# %%
geotech_risk_df['has_geotechnical_risk'].values[geotech_risk_df['has_geotechnical_risk'].isna()] = '0'

# %%
geotech_risk_df['has_geotechnical_risk'].isna().sum()
# Out:
# 0

# %%
geotech_risk_df.isna().sum()
# Out:
# building_id                              0
# district_id                              0
# vdcmun_id                                0
# ward_id                                  0
# has_geotechnical_risk                    0
# has_geotechnical_risk_land_settlement    0
# has_geotechnical_risk_fault_crack        0
# has_geotechnical_risk_liquefaction       0
# has_geotechnical_risk_landslide          0
# has_geotechnical_risk_rock_fall          0
# has_geotechnical_risk_flood              0
# has_geotechnical_risk_other              0
# dtype: int64

# %%
for col in geotech_risk_df.columns:
    print('{} >>>>>>>>>>>>>>>>>>>>>'.format(col))
    print(geotech_risk_df[col].value_counts())
# Out:
# building_id >>>>>>>>>>>>>>>>>>>>>
# 222106000471    1
# 224805000591    1
# 240607001241    1
# 304607002131    1
# 212506001531    1
#                ..
# 224806000981    1
# 122701000141    1
# 224805000831    1
# 235306000561    1
# 366203000401    1
# Name: building_id, Length: 762106, dtype: int64
# district_id >>>>>>>>>>>>>>>>>>>>>
# 24    98019
# 31    90994
# 30    89122
# 23    88741
# 36    78074
# 28    77148
# 20    68750
# 22    60639
# 21    58623
# 12    39352
# 29    12644
# Name: district_id, dtype: int64
# vdcmun_id >>>>>>>>>>>>>>>>>>>>>
# 3104    32696
# 2005    15659
# 3009    15239
# 2802    15204
# 2001    15002
#         ...
# 2406     2746
# 2905     2611
# 2903     2589
# 2902     2224
# 2901     1981
# Name: vdcmun_id, Length: 110, dtype: int64
# ward_id >>>>>>>>>>>>>>>>>>>>>
# 310405    2584
# 310404    2440
# 310412    2337
# 200506    2048
# 310411    2001
#           ...
# 360501     221
# 290204     182
# 360601     173
# 280801     160
# 290202     159
# Name: ward_id, Length: 945, dtype: int64
# has_geotechnical_risk >>>>>>>>>>>>>>>>>>>>>
# 0    652459
# 1    109647
# Name: has_geotechnical_risk, dtype: int64
# has_geotechnical_risk_land_settlement >>>>>>>>>>>>>>>>>>>>>
# 0    733055
# 1     29051
# Name: has_geotechnical_risk_land_settlement, dtype: int64
# has_geotechnical_risk_fault_crack >>>>>>>>>>>>>>>>>>>>>
# 0    721558
# 1     40548
# Name: has_geotechnical_risk_fault_crack, dtype: int64
# has_geotechnical_risk_liquefaction >>>>>>>>>>>>>>>>>>>>>
# 0    759976
# 1      2130
# Name: has_geotechnical_risk_liquefaction, dtype: int64
# has_geotechnical_risk_landslide >>>>>>>>>>>>>>>>>>>>>
# 0    701032
# 1     61074
# Name: has_geotechnical_risk_landslide, dtype: int64
# has_geotechnical_risk_rock_fall >>>>>>>>>>>>>>>>>>>>>
# 0    730113
# 1     31993
# Name: has_geotechnical_risk_rock_fall, dtype: int64
# has_geotechnical_risk_flood >>>>>>>>>>>>>>>>>>>>>
# 0    753175
# 1      8931
# Name: has_geotechnical_risk_flood, dtype: int64
# has_geotechnical_risk_other >>>>>>>>>>>>>>>>>>>>>
# 0    761291
# 1       815
# Name: has_geotechnical_risk_other, dtype: int64

# %%
geotech_risk_df.columns
# Out:
# Index(['building_id', 'district_id', 'vdcmun_id', 'ward_id',
#        'has_geotechnical_risk', 'has_geotechnical_risk_land_settlement',
#        'has_geotechnical_risk_fault_crack',
#        'has_geotechnical_risk_liquefaction', 'has_geotechnical_risk_landslide',
#        'has_geotechnical_risk_rock_fall', 'has_geotechnical_risk_flood',
#        'has_geotechnical_risk_other'],
#       dtype='object')

# %%
for col in geotech_risk_df.columns:
    geotech_risk_df[col]= pd.to_numeric(geotech_risk_df[col])
# Out:
# /Users/lhams/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
geotech_risk_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 762106 entries, 0 to 762105
# Data columns (total 12 columns):
# building_id                              762106 non-null int64
# district_id                              762106 non-null int64
# vdcmun_id                                762106 non-null int64
# ward_id                                  762106 non-null int64
# has_geotechnical_risk                    762106 non-null int64
# has_geotechnical_risk_land_settlement    762106 non-null int64
# has_geotechnical_risk_fault_crack        762106 non-null int64
# has_geotechnical_risk_liquefaction       762106 non-null int64
# has_geotechnical_risk_landslide          762106 non-null int64
# has_geotechnical_risk_rock_fall          762106 non-null int64
# has_geotechnical_risk_flood              762106 non-null int64
# has_geotechnical_risk_other              762106 non-null int64
# dtypes: int64(12)
# memory usage: 69.8 MB

# %%
geotech_risk_df.to_pickle("data/pickles/geotech_risk_df.pkl")
